# %%
import soccerdata as sd
import pandas as pd

# Verify Chilean league is now available
print(sd.FBref.available_leagues())

# %%
fbref = sd.FBref(
    leagues="CHI-Primera Division",
    seasons=2024,     # Solo una temporada primero para testear
    no_cache=True
)

player_stats = fbref.read_player_season_stats(stat_type="standard")
print(f"Shape: {player_stats.shape}")
player_stats.head(10)
